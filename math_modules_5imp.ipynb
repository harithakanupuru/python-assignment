# %% [markdown]
# 1. Write a program to calculate the square root of a number using the math module.

# %%
num = 27
cbrt_val = num ** (1/3)
print(cbrt_val)
# Out:
# 3.0

# %% [markdown]
# 2.Find the cube root of a given number using mathematical operations.

# %%
num = 29
cbrt = num ** (1/3)
print(cbrt)
# Out:
# 3.072316825685847

# %% [markdown]
# 3.Calculate the factorial of a number using math.factorial().

# %%
import math
num1 = 12
num2 =9
fact = math.factorial(num)
print("tha factorial of",num, "is",fact)
# Out:
# tha factorial of 29 is 8841761993739701954543616000000

# %% [markdown]
# 4. Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().

# %%
import math
num1 = 12
num2 = 14
gcd = math.gcd(num1, num2)
print("the gcd of", num1, "and",num2, "is",gcd)
# Out:
# the gcd of 12 and 14 is 2

# %% [markdown]
# 5.Find the LCM of two numbers using math.lcm().

# %%
import math
num1 = 13
num2 = 16
lcm = math.lcm(num1, num2)
print("the lcm of", num1, "and",num2, "is",lcm)
# Out:
# the lcm of 13 and 16 is 208

# %% [markdown]
# 6.Calculate the value of 5 raised to the power of 8 using math.pow().

# %%
import math
result = math.pow(5,8)
print(" 5 raised to the power of 8 is", result)
# Out:
#  5 raised to the power of 8 is 390625.0

# %% [markdown]
# 7.Find the absolute value of a negative decimal number using math.fabs().

# %%
import math
num = -18
abs_value = math.fabs(num)
print("the absolute value of", num, "is", abs_value)
# Out:
# the absolute value of -18 is 18.0

# %% [markdown]
# 8.Round a floating-point number up using math.ceil().

# %%
import math
num = 23.5
ceil_value  = math.ceil(num)
print("the ceil value of", num, "is", ceil_value)
# Out:
# the ceil value of 23.5 is 24

# %% [markdown]
# 9.Round a floating-point number down using math.floor().

# %%
import math
num = 45.6
floor_value  = math.floor(num)
print("the floor value of", num, "is", floor_value)
# Out:
# the floor value of 45.6 is 45

# %% [markdown]
# 10. Round a floating-point number to the nearest integer using round().

# %%
import math
num = 13
rounded = round(num)
print("the round value of", num, "is", rounded)
# Out:
# the round value of 13 is 13

# %% [markdown]
# 11.Find the remainder of two numbers using math.fmod().

# %%
import math
a = 6
b = 7
remainder = math.fmod(a, b)
print("the remainder of", a, "and", b, "is", remainder)
# Out:
# the remainder of 6 and 7 is 6.0

# %% [markdown]
# 12.Find the quotient and remainder using divmod().

# %%
import math
a = 10
b = 12
quotient, remainder = divmod(a, b)
print("the quotient of", a, "and", b, "is", quotient)
# Out:
# the quotient of 10 and 12 is 0

# %% [markdown]
# 13.Calculate the sine, cosine, and tangent of 45 degrees.

# %%
import math
angle_deg = 45
angle_rad = math.radians(angle_deg)
sin_val = math.sin(angle_rad)
cos_val = math.cos(angle_rad)
tan_val = math.tan(angle_rad)
print("sin(45) =", sin_val)
print("cos(45) =", cos_val)
print("tan(45) =", tan_val)
# Out:
# sin(45) = 0.7071067811865475
# cos(45) = 0.7071067811865476
# tan(45) = 0.9999999999999999

# %% [markdown]
# 14. Convert an angle from degrees to radians.

# %%
import math
angle_deg = 40
angle_rad = math.radians(angle_deg)
print(angle_deg, "degrees=",angle_rad, "radians")
# Out:
# 40 degrees= 0.6981317007977318 radians

# %% [markdown]
# 15.Convert an angle from radians to degrees.

# %%
import math
angle_rad = 0.6981
angle_deg = math.degrees(angle_rad)
print(angle_rad, "radians=",angle_deg, "degrees")
# Out:
# 0.6981 radians= 39.998183678082775 degrees

# %% [markdown]
# 16.Find the logarithm (base 10) of a number using math.log10().

# %%
import math
num = 100
log_value = math.log10(num)
print("log base 10 of", num, "is", log_value)
# Out:
# log base 10 of 100 is 2.0

# %% [markdown]
# 17.Find the natural logarithm of a number using math.log().

# %%
import math
num = 3.56436
in_value = math.log(num)
print("natural log of", num, "is", in_value)
# Out:
# natural log of 3.56436 is 1.2709845146083962

# %% [markdown]
# 18.Calculate e raised to the power of x using math.exp().

# %%
import math
x = 2
result = math.exp(x)
print("e raised to the power of", x, "is:", result)
# Out:
# e raised to the power of 2 is: 7.38905609893065

# %% [markdown]
# 19. Find the value of π (pi) and Euler's number (e) from the math module.

# %%
import math
pi_value = math.pi
e_value = math.e
print("value of pi:", pi_value)
print("value of e:", e_value)
# Out:
# value of pi: 3.141592653589793
# value of e: 2.718281828459045

# %% [markdown]
# 20.Find the distance between two points using math.dist().

# %%
import math
math.dist((1,2),(3,4))
# Out:
# the distance between (1, 2) and (3, 4) is: 2.8284271247461903

# %% [markdown]
# 21.Calculate the hypotenuse of a right triangle using math.hypot().

# %%
import math
math.hypotenuse(7,8)
# Out:
# the hypotenuse of a right triangle with sides 4 and 5 is: 6.4031242374328485

# %% [markdown]
# 22.Find the combination (nCr) using math.comb().

# %%
import math
n = 5
C = 6
r = 2
combination = math.comb(n, r)
print(r,combination)
# Out:
# 2 10

# %% [markdown]
# 23.Find the permutation (nPr) using math.perm().

# %%
import math
math.perm(3,4)
# Out:
# 5p2 = 20

# %% [markdown]
# 24.Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

# %%
import math
x = 10
print(math.isfinite(x))
print(math.isinf(x))
print(math.isnan(x))
# Out:
# True
# False
# False

# %% [markdown]
# 25.Find the product of all numbers in a list using math.prod().

# %%
numbers = [2,3,4,5]
product = math.prod(numbers)
print(product)
# Out:
# 120

# %% [markdown]
# 26.Find the sum of square roots of all numbers in a list.

# %%
import math
numbers = [2,3,4,5]
sum_of_sqrts= sum(math.sqrt(num) for num in numbers)
print("list:", numbers)
print("sum of square roots:", sum_of_sqrts)
# Out:
# list: [2, 3, 4, 5]
# sum of square roots: 7.382332347441762

# %% [markdown]
# 27.Find the largest integer less than or equal to the square root of a given number.

# %%
import math
num = 50
result = math.floor(math.sqrt(num))
print(f"the lagest integer <= sqrt({num}): {result}")
# Out:
# the lagest integer <= sqrt(50): 7

# %% [markdown]
# 28.Calculate compound interest using math.pow().

# %%
import math
math.pow(34,5)
# Out:
# amount: 419.3024563369773
# compound interest: 409.3024563369773

# %% [markdown]
# 29.Find the area and circumference of a circle using math.pi.

# %%
import math
r = 8
print(math.pi*r*r)
print(2*math.pi*r)
# Out:
# enter the radius of the circle:16
# area of the circle: 804.247719318987
# circumference of the circle: 100.53096491487338

# %% [markdown]
# 30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

# %%
import math
print(math.sqrt(25))
print(math.factorial(5))
print(math.log(10))
print(math.pow(2, 3))
print(math.sin(math.radians(30)))
print(math.gcd(12, 24))
print(math.lcm(12, 24))
# Out:
# 5.0
# 120
# 2.302585092994046
# 8.0
# 0.49999999999999994
# 12
# 24

# %% [markdown]
# 1.Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

# %%
a = float(input("Enter 1st number: "))
b = float(input("Enter 2nd number: "))
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Enter 1st number: 12
# Enter 2nd number: 9
# Addition: 21.0
# Subtraction: 3.0
# Multiplication: 108.0
# Division: 1.3333333333333333
# Floor Division: 1.0
# Modulus: 3.0
# Exponentiation: 5159780352.0

# %% [markdown]
# 2.Swap two numbers without using a third variable.

# %%
a = 4
b = 7
x=x+y
y=x-y
x=x-y
print(x)
print(y)

# %% [markdown]
# 3.Find whether a number is even or odd using the modulus operator.

# %%
n = 5
if n % 2 == 0:
    print(n, "is even")
else:
    print(n, "is odd")

# %% [markdown]
# 4.Reverse a three-digit number using arithmetic operators.

# %%
n = 456
rev = 0
while n > 0:
    digit = n % 10
    rev = rev * 10 + digit
    n //= 1

# %% [markdown]
# 5.Find the last digit and first digit of a given number.

# %%
n = 32
print(n%15)
print(n//16)
# Out:
# 2
# 2

# %% [markdown]
# 6.Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

# %%
x = 20
print("initial:x",x)
x += 14
print("x += 14 ->, x")
x -= 18
print("x -= 18 ->, x")
x *=6
print("x *= 6 ->, x")
x /= 40
print("x /= 40 ->, x")
# Out:
# initial:x 20
# x += 14 ->, x
# x -= 18 ->, x
# x *= 6 ->, x
# x /= 40 ->, x

# %% [markdown]
# 7.Update a bank account balance using compound assignment operators.

# %%
balance = 10000
balance *= 4000
print("new balance:" ,b)
b-=3000
print("balance:",b)
b//=2000
print("balance:",b)
b%=1000
print("balance:",b)
# Out:
# new balance: 15
# balance: -2985
# balance: -2
# balance: 998

# %% [markdown]
# 8.Calculate the total marks using += inside a loop.

# %%
marks = [75,97,86,69]
total = 0
for m in marks:
  total += m
  print("total marks:", total)
# Out:
# total marks: 75
# total marks: 172
# total marks: 258
# total marks: 327

# %% [markdown]
# 9.Compare two numbers and print the larger number.

# %%
a = 12
b = 15
if a > b:
    print(a)
else:
    print(b)
# Out:
# 15

# %% [markdown]
# 10.Check whether three numbers are equal.

# %%
a = 45
b = 45
c = 45
if a == b == c:
    print("all numbers are equal")
else:
    print("all numbers are not equal")
# Out:
# all numbers are equal

# %% [markdown]
# 11.Find the largest among three numbers using comparison operators.

# %%
a = 10
b = 23
c = 34
if a >= b and a >= c:
    print(a)
elif b >= a and b >= c:
    print(b)
else:
    print(c)
# Out:
# 34

# %% [markdown]
# 12.Check whether a student is eligible to vote based on age.

# %%
age = 18
if age >= 18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# you are eligible to vote

# %% [markdown]
# 13.Check if a person is eligible for a loan (age > 21 AND salary > 30000).

# %%
age = 21
salary = 30000
if age > 21 and salary > 30000:
    print("eligible for a loan")
else:
  print("not eligible for loan")
# Out:
# not eligible for loan

# %% [markdown]
# 14.Check if a number lies between 10 and 100 using logical operators.

# %%
num = 35
if num >= 10 and num <= 100:
    print("lies")
else:
  print("not lies")
# Out:
# lies

# %% [markdown]
# 15.Validate username and password using logical operators.

# %%
username = "haritha"
password = "217"
if username =="hariha"and password ==217:
    print("valid username and password")
else:
  print("invalid username or password")
# Out:
# invalid username or password

# %% [markdown]
# 16.Determine whether a year is a leap year using logical conditions.

# %%
year = 2026
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# 2026 is not a leap year

# %% [markdown]
# 17.Find the bitwise AND, OR, XOR of two numbers.

# %%
a=1010
b=1010
print(a&b)
print(a|b)
print(a^b)
# Out:
# 1010
# 1010
# 0

# %% [markdown]
# 18.Perform left shift and right shift operations.

# %%
x = 20
print(x<<2)
print(x>>2)
# Out:
# 80
# 5

# %% [markdown]
# 19.Check whether a number is even using a bitwise operator.

# %%
num = 10
if num & 1 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# 10 is even

# %% [markdown]
# 20.Swap two numbers using the XOR operator.

# %%
a = 23
b = 45
swap = a ^ b
a = swap ^ a
b = swap ^ b
print(a)
print(b)
# Out:
# 45
# 23

# %% [markdown]
# 21.Count how many bits are set to 1 in a number using bitwise operations.

# %%
a=[1,2,3,4,5,6]
print(a.count(1))
# Out:
# 1

# %% [markdown]
# 22.Demonstrate the difference between is and ==.

# %%
a=30
b=26
a==b and a is b
# Out:
# False

# %% [markdown]
# 23.Check whether two variables refer to the same list object.

# %%
x=[1,2,3,4]
y=[3,5,7,6]
if x==y:
  print("same")
else:
    print("not same")
# Out:
# not same

# %% [markdown]
# 24.Show the behavior of is not with integers and lists.

# %%
a = [1,2,3,4]
b = [1,4,6,5]
if a is not b:
   print("not same")
else:
  print("same")
# Out:
# not same

# %% [markdown]
# 25.Check whether a character exists in a string.

# %%
a=["machine","learning"]
print("machine"in (a))
# Out:
# True

# %% [markdown]
# 26.Check whether a number exists in a list.

# %%
numbers = [10, 20, 30, 40, 50]
num = int(input("enter a number to check: "))
if num in numbers:
    print(num, "exists in the list")
else:
  print(num, "does not exist in the list")
# Out:
# enter a number to check: 23
# 23 does not exist in the list

# %% [markdown]
# 27.Count how many vowels in a string belong to a predefined vowel list using in.

# %%
text = input("enter a string: ")
vowels = ["a","e","i","o","u"]
count = 0
for i in text:
    if i.lower() in vowels:
        count += 1
print("Total vowels:", count)
# Out:
# enter a string: 2
# Total vowels: 0

# %% [markdown]
# 28.Build a simple calculator using arithmetic and comparison operators.

# %%
a = float(input("enter 1st number: "))
b = float(input("enter 2nd number: "))
operation = input("enter operation (+, -, *, /): ")
if operation == "+":
    result = a + b
elif operation == "-":
    result = a - b
# Out:
# enter 1st number: 54
# enter 2nd number: 65
# enter operation (+, -, *, /): 69

# %% [markdown]
# 29.Create a grading system using comparison and logical operators.

# %%
marks = int(input("enter marks: "))
if marks >= 90:
    grade = "A"
elif marks >= 80:
    grade = "B"
elif marks >= 70:
    grade = "C"
elif marks >= 60:
    grade = "D"
else:
    grade = "F"
print("grade:", grade)
# Out:
# enter marks: 67
# grade: D

# %% [markdown]
# 30.Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.
